# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather Map API Call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high = 90.000, size =2000)
lngs = np.random.uniform(low= -180.000, high =180.000, size =2000)

lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

print(coordinates)
# Out:
# [(2.9424979292688107, -9.225257652248871), (32.270334838653824, 146.8554418405264), (-22.680672026272106, -38.14450501014872), (5.366821688943347, 107.60371608942603), (-48.83506075654266, -102.37580347470522), (-21.232628958496036, -104.26792117651405), (29.999584252441778, -157.17898483428772), (-18.42054516692579, -156.36882714146086), (-77.74167909147641, -131.02884458236448), (-10.325410282112855, 89.84050860509137), (47.64930730681763, 57.44694376706937), (-74.54554256374118, -104.01369082731091), (41.50022436530179, 63.63303871744486), (-62.35354402422722, -70.87912480131143), (-73.6453697276509, -176.9532399058619), (-50.536449761202256, -25.652647151548138), (-50.43974448065468, 51.18021936290151), (-0.7315944695399423, -29.951541796988153), (51.032695048233506, -20.82435111570709), (-74.31329980621558, 9.237827559948897), (-63.72300413214752, -113.05948949610064), (60.3898158983863, -104.34097391826037), (-25.356885030365675, -109.49335411924957), (67.33894825024245, -177.27947343411543), (-61.94507524405239, 153.78348249028733), (38.90151077873631, 92.84559856711695), (27.805289722217097, -88.96263412579215), (-30.434234345114852, 28.66708469689422), (74.91041411015263, 105.11134413162301), (51.41604429641137, -61.28642944349998), (-33.98320087961355, -174.7412826661488), (-50.14834323411554, 125.45914230373955), (42.712497967687824, -167.31105279334062), (28.438188612741072, 124.39949395498076), (82.1325770270862, -36.58709212052989), (12.641443430013666, 154.4193554718707), (-15.867106101987929, 53.15742338173868), (37.952049390798564, 107.62927736727022), (-1.1593655301984427, 40.39021575277283), (-62.72567337722465, -89.53517009646004), (1.0429549063372292, 25.335195001781074), (21.931647776782825, 69.62293834606811), (85.21020993836248, -169.323253801751), (68.768021450672, 90.2644911635154), (2.130491674223734, 159.9019089239166), (-46.67080466682806, 15.01638719631498), (6.5004126518185785, -94.22834101926594), (86.94541973333241, -7.7124717422084075), (89.91033526183341, -136.3944643980837), (2.9599455161057335, 125.54632279350284), (-39.27393830417323, 179.78484916057585), (-20.147610696425076, -144.07401638131935), (-82.22381923442927, 87.57705653718489), (-2.1431049183693034, 31.271635664084982), (-28.316675943262233, -152.19600162290445), (-23.51585164569184, -176.0242138790537), (-33.194095421136225, -19.929330585256707), (-36.90493745790846, 54.5512454757677), (38.73750786732836, 53.14713872471884), (-1.0496948281156477, 127.1733245966746), (68.18465476334202, 89.23455384132711), (40.84418106518817, -102.43643972866725), (41.130865320259744, 48.420103785066175), (87.24416943732768, 142.5387980556655), (78.48621253966908, -107.50667428964489), (50.638578407729284, 149.91567398627404), (-37.60052714016103, -178.5341952480447), (-68.58046441164173, 128.16402434725433), (-21.584621014471978, -14.963860138446364), (59.290719616871115, 77.05794650800146), (62.38985774741738, 130.66334413751895), (-30.13863894489569, -124.86175800104994), (-28.794347360925848, 47.772947613708396), (41.03966588706896, -122.02291353549964), (-77.60523270120017, -39.17736084402253), (-2.2154384215577636, -113.64658763277356), (-25.23449072489811, 83.53438431423854), (-20.304718727608304, -89.74776893403586), (-24.12380946030622, 47.551692967402914), (-30.47529463895932, -90.98236004781572), (32.20862214109026, 91.54168405330017), (-75.48098445185042, 161.27260207427264), (-38.75602028852586, 104.07906577759087), (52.45980264888237, -50.33771660937978), (-19.973720825492194, 171.70911441396828), (23.19232980591022, -66.3633258214407), (-84.17310522779975, -16.926144360759082), (-33.870313655992824, 161.32560413916622), (80.95482073656311, 82.59750618021263), (73.24063946744783, 66.43369718907934), (-17.64720121121445, -54.49460352998004), (-44.982294396752756, -116.78910052428066), (-77.63474426642755, -41.40866016287046), (45.84545166085411, 26.516992172882055), (52.84114571214391, -31.68573615603202), (8.852390864729102, -140.2 ...

# %%
# Get the nearest city using citipy

from citipy import citipy

# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combiantion.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
print(cities)
# Out:
# ['harper', 'hasaki', 'sao joao da barra', 'paka', 'castro', 'puerto ayora', 'kapaa', 'avarua', 'rikitea', 'bengkulu', 'shubarshi', 'punta arenas', 'gazli', 'ushuaia', 'vaini', 'cidreira', 'taolanaro', 'touros', 'dingle', 'hermanus', 'la ronge', 'egvekinot', 'hobart', 'hami', 'estelle', 'kokstad', 'khatanga', 'havre-saint-pierre', 'esperance', 'bethel', 'shenjiamen', 'tasiilaq', 'kavieng', 'antalaha', 'yinchuan', 'garissa', 'kisangani', 'bhanvad', 'barrow', 'talnakh', 'kieta', 'champerico', 'illoqqortoormiut', 'tuktoyaktuk', 'bitung', 'tolaga bay', 'tautira', 'busselton', 'nshamba', 'mataura', 'jamestown', 'balkanabat', 'tidore', 'snezhnogorsk', 'sterling', 'quba', 'nizhneyansk', 'yellowknife', 'vostok', 'new norfolk', 'strezhevoy', 'borogontsy', 'shasta lake', 'coahuayana', 'grand river south east', 'pisco', 'vangaindrano', 'lebu', 'lasa', 'bluff', 'bonavista', 'isangel', 'hatillo', 'port macquarie', 'dikson', 'amderma', 'coxim', 'tulnici', 'hilo', 'luderitz', 'tiksi', 'butaritari', 'souillac', 'iwaki', 'avera', 'shahr-e babak', 'albany', 'salalah', 'saint-philippe', 'norman wells', 'we', 'mahebourg', 'hamilton', 'dukat', 'codrington', 'bubaque', 'pevek', 'rawannawi', 'camacha', 'yunjinghong', 'barentsburg', 'comodoro rivadavia', 'naze', 'pouebo', 'haifa', 'chara', 'vila', 'ribeira grande', 'richards bay', 'nishihara', 'atuona', 'barcelos', 'nemuro', 'hithadhoo', 'fortuna', 'chipinge', 'viedma', 'georgetown', 'bambous virieux', 'ierapetra', 'kibre mengist', 'karratha', 'mattru', 'husavik', 'thompson', 'sioux lookout', 'prince rupert', 'san patricio', 'katsuura', 'upata', 'port elizabeth', 'baft', 'upernavik', 'nikolskoye', 'mandali', 'the valley', 'te anau', 'pacific grove', 'rosarito', 'constantine', 'mayor pablo lagerenza', 'santa ines', 'apomu', 'bathsheba', 'itoman', 'alvorada', 'bereda', 'ust-omchug', 'sur', 'saskylakh', 'takaka', 'jalu', 'boende', 'narsaq', 'ancud', 'yulara', 'michigan city', 'ouango', 'pelym', 'carnarvon', 'saint george', 'trinidad', 'biloela', 'lorengau', 'coihaique', 'alihe', 'morant bay', 'petropavlovsk-kamchatskiy', 'petauke', 'itarema', 'port alfred', 'meadow lake', 'waipawa', 'kaitangata', 'kloulklubed', 'dosso', 'nanakuli', 'huarmey', 'horsham', 'arman', 'bay city', 'lavrentiya', 'mys shmidta', 'lakatoro', 'davila', 'severo-kurilsk', 'ponta do sol', 'zhirnovsk', 'victoria', 'lieksa', 'sakakah', 'ilulissat', 'guerrero negro', 'lompoc', 'klyuchi', 'sibiti', 'dalvik', 'tarauaca', 'fallon', 'arraial do cabo', 'ambilobe', 'kultuk', 'paamiut', 'cape town', 'buala', 'mar del plata', 'gamba', 'santa maria', 'praia', 'ust-uda', 'faanui', 'sukhinichi', 'santa vitoria do palmar', 'abha', 'east london', 'beira', 'srednekolymsk', 'puerto cortes', 'port hawkesbury', 'lipno', 'moussoro', 'charlestown', 'nome', 'belushya guba', 'sochaczew', 'sentyabrskiy', 'bo phloi', 'bud', 'iqaluit', 'pangnirtung', 'nizhniy kuranakh', 'kamenka', 'thinadhoo', 'cabo san lucas', 'san andres', 'atlanta', 'tadine', 'ahome', 'krabi', 'qaanaaq', 'bitkine', 'palmer', 'makat', 'dunedin', 'hobyo', 'los llanos de aridane', 'westport', 'voh', 'evensk', 'gilbues', 'clyde river', 'pirgos', 'torbay', 'namatanai', 'chuy', 'buta', 'nouadhibou', 'jahrom', 'qiongshan', 'beringovskiy', 'haines junction', 'sonoita', 'bondo', 'erdenet', 'bridlington', 'sao filipe', 'winfield', 'ostrovnoy', 'rawson', 'moron', 'geraldton', 'kavaratti', 'hanmer springs', 'chokurdakh', 'bhatkal', 'greenwood', 'rundu', 'suzu', 'pagudpud', 'tandil', 'bamberg', 'ipixuna', 'kamenskoye', 'caravelas', 'tura', 'takoradi', 'adrar', 'aykhal', 'biak', 'vanavara', 'kodiak', 'salobrena', 'longyearbyen', 'yaan', 'arnedo', 'sinnamary', 'coruripe', 'henties bay', 'mirabad', 'northam', 'saint-georges', 'gwadar', 'broome', 'kirkland lake', 'oksfjord', 'dunhua', 'bredasdorp', 'chumikan', 'vardo', 'oktyabrskiy', 'juneau', 'abbeville', 'victor harbor', 'baherden', 'elliot', 'provideniya', 'eureka', 'college', 'faya', 'airai', 'korla', 'marcona', 'taoudenni', 'vanimo', 'calabozo', 'honning ...

# %%
# Declare an empty list to hold the weather data
city_data =[]

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create counterss for the record numbers 1-50 and the set counter
record_count =1
set_count =1

# Instead of using two for loops, we can use the enumerate() method as an alternative way 
# to iterate through the list of cities
# and retrieve both the index, and the city from the list.
# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_city=city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
       
       
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                  "Country": city_country,
                  "Lat": city_lat,      
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | harper
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | paka
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | shubarshi
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | gazli
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | dingle
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | la ronge
# Processing Record 22 of Set 1 | egvekinot
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | hami
# Processing Record 25 of Set 1 | estelle
# Processing Record 26 of Set 1 | kokstad
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | havre-saint-pierre
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | shenjiamen
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | antalaha
# Processing Record 35 of Set 1 | yinchuan
# Processing Record 36 of Set 1 | garissa
# Processing Record 37 of Set 1 | kisangani
# Processing Record 38 of Set 1 | bhanvad
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | kieta
# Processing Record 42 of Set 1 | champerico
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | bitung
# Processing Record 46 of Set 1 | tolaga bay
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | nshamba
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | balkanabat
# Processing Record 3 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 2 | snezhnogorsk
# Processing Record 5 of Set 2 | sterling
# Processing Record 6 of Set 2 | quba
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | strezhevoy
# Processing Record 12 of Set 2 | borogontsy
# Processing Record 13 of Set 2 | shasta lake
# Processing Record 14 of Set 2 | coahuayana
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | vangaindrano
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | lasa
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | bonavista
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | hatillo
# Processing Record 24 of Set 2 | port macquarie
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | coxim
# Processing Record 28 of Set 2 | tulnici
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | iwaki
# Processing Record 35 of Set 2 | avera
# Processing Record 36 of Set 2 | shahr-e babak
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | norman wells
# Processing Record 41 of Set 2 | we
# City not found. Skipping...
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | hamilton
# Processing Record 44 of Set 2 | dukat
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | bubaque
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 2 | camacha
# Processing Record 50 of Set 2 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | naze
# Processing Record 4 of Set 3 | pouebo
# Processing Record 5 of Set 3 | haifa
# Processing Record 6 of Set 3 | chara
# Processing Record 7 of Set 3 | vila
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | richards bay
# Processing Record 10 of Set 3 | nishihara
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | barcelos
# Processing Record 13 of Set 3 | nemuro
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | chipinge
# Processing Record 17 of Set 3 | viedma
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | ierapetra
# Processing Record 21 of Set 3 | kibre mengist
# Processing Record 22 of Set 3 | karratha
# Processing Record 23 of Set 3 | mattru
# Processing Record 24 of Set 3 | husavik
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | sioux lookout
# Processing Record 27 of Set 3 | prince rupert
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | upata
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | baft
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | mandali
# Processing Record 36 of Set 3 | the valley
# Processing Record 37 of Set 3 | te anau
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | rosarito
# Processing Record 40 of Set 3 | constantine
# Processing Record 41 of Set 3 | mayor pablo lagerenza
# Processing Record 42 of Set 3 | santa ines
# Processing Record 43 of Set 3 | apomu
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | itoman
# Processing Record 46 of Set 3 | alvorada
# Processing Record 47 of Set 3 | bereda
# Processing Record 48 of Set 3 | ust-omchug
# Processing Record 49 of Set 3 | sur
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | takaka
# Processing Record 2 of Set 4 | jalu
# Processing Record 3 of Set 4 | boende
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | michigan city
# Processing Record 8 of Set 4 | ouango
# Processing Record 9 of Set 4 | pelym
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | trinidad
# Processing Record 13 of Set 4 | biloela
# Processing Record 14 of Set 4 | lorengau
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | alihe
# Processing Record 17 of Set 4 | morant bay
# Processing Record 18 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 4 | petauke
# Processing Record 20 of Set 4 | itarema
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | meadow lake
# Processing Record 23 of Set 4 | waipawa
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | kloulklubed
# Processing Record 26 of Set 4 | dosso
# Processing Record 27 of Set 4 | nanakuli
# Processing Record 28 of Set 4 | huarmey
# Processing Record 29 of Set 4 | horsham
# Processing Record 30 of Set 4 | arman
# Processing Record 31 of Set 4 | bay city
# Processing Record 32 of Set 4 | lavrentiya
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | lakatoro
# Processing Record 35 of Set 4 | davila
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | zhirnovsk
# Processing Record 39 of Set 4 | victoria
# Processing Record 40 of Set 4 | lieksa
# Processing Record 41 of Set 4 | sakakah
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | klyuchi
# Processing Record 46 of Set 4 | sibiti
# Processing Record 47 of Set 4 | dalvik
# Processing Record 48 of Set 4 | tarauaca
# Processing Record 49 of Set 4 | fallon
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | ambilobe
# Processing Record 2 of Set 5 | kultuk
# Processing Record 3 of Set 5 | paamiut
# Processing Record 4 of Set 5 | cape town
# Processing Record 5 of Set 5 | buala
# Processing Record 6 of Set 5 | mar del plata
# Processing Record 7 of Set 5 | gamba
# Processing Record 8 of Set 5 | santa maria
# Processing Record 9 of Set 5 | praia
# Processing Record 10 of Set 5 | ust-uda
# Processing Record 11 of Set 5 | faanui
# Processing Record 12 of Set 5 | sukhinichi
# Processing Record 13 of Set 5 | santa vitoria do palmar
# Processing Record 14 of Set 5 | abha
# Processing Record 15 of Set 5 | east london
# Processing Record 16 of Set 5 | beira
# Processing Record 17 of Set 5 | srednekolymsk
# Processing Record 18 of Set 5 | puerto cortes
# City not found. Skipping...
# Processing Record 19 of Set 5 | port hawkesbury
# Processing Record 20 of Set 5 | lipno
# Processing Record 21 of Set 5 | moussoro
# Processing Record 22 of Set 5 | charlestown
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | sochaczew
# Processing Record 26 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | bo phloi
# Processing Record 28 of Set 5 | bud
# Processing Record 29 of Set 5 | iqaluit
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | nizhniy kuranakh
# Processing Record 32 of Set 5 | kamenka
# Processing Record 33 of Set 5 | thinadhoo
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | san andres
# Processing Record 36 of Set 5 | atlanta
# Processing Record 37 of Set 5 | tadine
# Processing Record 38 of Set 5 | ahome
# Processing Record 39 of Set 5 | krabi
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | bitkine
# Processing Record 42 of Set 5 | palmer
# Processing Record 43 of Set 5 | makat
# Processing Record 44 of Set 5 | dunedin
# Processing Record 45 of Set 5 | hobyo
# Processing Record 46 of Set 5 | los llanos de aridane
# Processing Record 47 of Set 5 | westport
# Processing Record 48 of Set 5 | voh
# Processing Record 49 of Set 5 | evensk
# Processing Record 50 of Set 5 | gilbues
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | pirgos
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | namatanai
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | buta
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 9 of Set 6 | qiongshan
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | sonoita
# Processing Record 13 of Set 6 | bondo
# Processing Record 14 of Set 6 | erdenet
# Processing Record 15 of Set 6 | bridlington
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | winfield
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | moron
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | hanmer springs
# Processing Record 24 of Set 6 | chokurdakh
# Processing Record 25 of Set 6 | bhatkal
# Processing Record 26 of Set 6 | greenwood
# Processing Record 27 of Set 6 | rundu
# Processing Record 28 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 29 of Set 6 | pagudpud
# Processing Record 30 of Set 6 | tandil
# Processing Record 31 of Set 6 | bamberg
# Processing Record 32 of Set 6 | ipixuna
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | caravelas
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | takoradi
# Processing Record 37 of Set 6 | adrar
# Processing Record 38 of Set 6 | aykhal
# Processing Record 39 of Set 6 | biak
# Processing Record 40 of Set 6 | vanavara
# Processing Record 41 of Set 6 | kodiak
# Processing Record 42 of Set 6 | salobrena
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | yaan
# Processing Record 45 of Set 6 | arnedo
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | coruripe
# Processing Record 48 of Set 6 | henties bay
# Processing Record 49 of Set 6 | mirabad
# Processing Record 50 of Set 6 | northam
# Processing Record 1 of Set 7 | saint-georges
# Processing Record 2 of Set 7 | gwadar
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | kirkland lake
# Processing Record 5 of Set 7 | oksfjord
# Processing Record 6 of Set 7 | dunhua
# Processing Record 7 of Set 7 | bredasdorp
# Processing Record 8 of Set 7 | chumikan
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | oktyabrskiy
# Processing Record 11 of Set 7 | juneau
# Processing Record 12 of Set 7 | abbeville
# Processing Record 13 of Set 7 | victor harbor
# Processing Record 14 of Set 7 | baherden
# Processing Record 15 of Set 7 | elliot
# Processing Record 16 of Set 7 | provideniya
# Processing Record 17 of Set 7 | eureka
# Processing Record 18 of Set 7 | college
# Processing Record 19 of Set 7 | faya
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | korla
# Processing Record 22 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | vanimo
# Processing Record 25 of Set 7 | calabozo
# Processing Record 26 of Set 7 | honningsvag
# Processing Record 27 of Set 7 | port hedland
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | bardsir
# Processing Record 31 of Set 7 | kidal
# Processing Record 32 of Set 7 | winnemucca
# Processing Record 33 of Set 7 | avenal
# Processing Record 34 of Set 7 | santa cruz
# Processing Record 35 of Set 7 | kitui
# Processing Record 36 of Set 7 | albion
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | pontianak
# Processing Record 40 of Set 7 | san jose
# Processing Record 41 of Set 7 | humaita
# Processing Record 42 of Set 7 | camopi
# Processing Record 43 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 7 | gemena
# Processing Record 45 of Set 7 | flinders
# Processing Record 46 of Set 7 | poykovskiy
# Processing Record 47 of Set 7 | hokitika
# Processing Record 48 of Set 7 | burica
# City not found. Skipping...
# Processing Record 49 of Set 7 | bundaberg
# Processing Record 50 of Set 7 | wairoa
# Processing Record 1 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 3 of Set 8 | camacari
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | nago
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | ukiah
# Processing Record 8 of Set 8 | tanout
# Processing Record 9 of Set 8 | sayyan
# Processing Record 10 of Set 8 | buritis
# Processing Record 11 of Set 8 | kafanchan
# Processing Record 12 of Set 8 | nalut
# Processing Record 13 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 8 | malpe
# Processing Record 15 of Set 8 | helena
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | suluq
# Processing Record 18 of Set 8 | tabory
# Processing Record 19 of Set 8 | ramhormoz
# Processing Record 20 of Set 8 | tilichiki
# Processing Record 21 of Set 8 | carahue
# Processing Record 22 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 23 of Set 8 | svetlogorsk
# Processing Record 24 of Set 8 | lata
# Processing Record 25 of Set 8 | xiamen
# Processing Record 26 of Set 8 | alta floresta
# Processing Record 27 of Set 8 | antanifotsy
# Processing Record 28 of Set 8 | berezovyy
# Processing Record 29 of Set 8 | xapuri
# Processing Record 30 of Set 8 | ayagoz
# Processing Record 31 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 8 | buin
# Processing Record 33 of Set 8 | jacareacanga
# Processing Record 34 of Set 8 | edd
# Processing Record 35 of Set 8 | tromso
# Processing Record 36 of Set 8 | uvat
# Processing Record 37 of Set 8 | maragogi
# Processing Record 38 of Set 8 | constitucion
# Processing Record 39 of Set 8 | asyut
# Processing Record 40 of Set 8 | auki
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | suhbaatar
# Processing Record 43 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 44 of Set 8 | vila velha
# Processing Record 45 of Set 8 | gondanglegi
# Processing Record 46 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 8 | leh
# Processing Record 48 of Set 8 | hulan ergi
# Processing Record 49 of Set 8 | mulege
# Processing Record 50 of Set 8 | asfi
# Processing Record 1 of Set 9 | pochutla
# Processing Record 2 of Set 9 | seoul
# Processing Record 3 of Set 9 | ballina
# Processing Record 4 of Set 9 | north bend
# Processing Record 5 of Set 9 | sorland
# Processing Record 6 of Set 9 | mbini
# Processing Record 7 of Set 9 | sambava
# Processing Record 8 of Set 9 | santa isabel do rio negro
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 9 | maine-soroa
# Processing Record 12 of Set 9 | rafai
# Processing Record 13 of Set 9 | bandar
# Processing Record 14 of Set 9 | brive-la-gaillarde
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | bonnyville
# Processing Record 17 of Set 9 | whitehorse
# Processing Record 18 of Set 9 | emba
# Processing Record 19 of Set 9 | pavilosta
# Processing Record 20 of Set 9 | labuhan
# Processing Record 21 of Set 9 | suzun
# Processing Record 22 of Set 9 | adamovka
# Processing Record 23 of Set 9 | soe
# Processing Record 24 of Set 9 | sokolovo
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | atar
# Processing Record 27 of Set 9 | cedar city
# Processing Record 28 of Set 9 | colgong
# Processing Record 29 of Set 9 | lincoln
# Processing Record 30 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 31 of Set 9 | iralaya
# Processing Record 32 of Set 9 | ust-kulom
# Processing Record 33 of Set 9 | saint-pierre
# Processing Record 34 of Set 9 | yeltsovka
# City not found. Skipping...
# Processing Record 35 of Set 9 | manoel urbano
# Processing Record 36 of Set 9 | malkapur
# Processing Record 37 of Set 9 | ayame
# Processing Record 38 of Set 9 | tibati
# Processing Record 39 of Set 9 | urumqi
# Processing Record 40 of Set 9 | tevriz
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | limon
# Processing Record 43 of Set 9 | iglas
# Processing Record 44 of Set 9 | kruisfontein
# Processing Record 45 of Set 9 | smederevo
# Processing Record 46 of Set 9 | asosa
# Processing Record 47 of Set 9 | elizabeth city
# Processing Record 48 of Set 9 | nanortalik
# Processing Record 49 of Set 9 | semey
# Processing Record 50 of Set 9 | forrest city
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | port blair
# Processing Record 3 of Set 10 | sinop
# Processing Record 4 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 10 | tiznit
# Processing Record 6 of Set 10 | vila do maio
# Processing Record 7 of Set 10 | vestmannaeyjar
# Processing Record 8 of Set 10 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 9 of Set 10 | hay river
# Processing Record 10 of Set 10 | wageningen
# Processing Record 11 of Set 10 | saldanha
# Processing Record 12 of Set 10 | mangawan
# Processing Record 13 of Set 10 | tezu
# Processing Record 14 of Set 10 | bela
# Processing Record 15 of Set 10 | amazar
# Processing Record 16 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 10 | tyrma
# Processing Record 18 of Set 10 | san mateo del mar
# Processing Record 19 of Set 10 | sept-iles
# Processing Record 20 of Set 10 | terrasini
# Processing Record 21 of Set 10 | am timan
# Processing Record 22 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 23 of Set 10 | aksu
# Processing Record 24 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 10 | staunton
# Processing Record 26 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 10 | tuatapere
# Processing Record 28 of Set 10 | chaumont
# Processing Record 29 of Set 10 | namibe
# Processing Record 30 of Set 10 | centralia
# Processing Record 31 of Set 10 | zhuanghe
# Processing Record 32 of Set 10 | utiel
# Processing Record 33 of Set 10 | gorontalo
# Processing Record 34 of Set 10 | paramonga
# Processing Record 35 of Set 10 | carman
# Processing Record 36 of Set 10 | bardiyah
# Processing Record 37 of Set 10 | belmopan
# Processing Record 38 of Set 10 | prescott
# Processing Record 39 of Set 10 | zhenhai
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 10 | kanke
# Processing Record 43 of Set 10 | requena
# Processing Record 44 of Set 10 | adre
# Processing Record 45 of Set 10 | chake chake
# Processing Record 46 of Set 10 | banos
# Processing Record 47 of Set 10 | wilkes-barre
# Processing Record 48 of Set 10 | mugur-aksy
# Processing Record 49 of Set 10 | beni suef
# Processing Record 50 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 11 | port moresby
# Processing Record 2 of Set 11 | asau
# Processing Record 3 of Set 11 | bu salim
# City not found. Skipping...
# Processing Record 4 of Set 11 | yuanping
# Processing Record 5 of Set 11 | carballo
# Processing Record 6 of Set 11 | dutse
# Processing Record 7 of Set 11 | leningradskiy
# Processing Record 8 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 9 of Set 11 | ye
# City not found. Skipping...
# Processing Record 10 of Set 11 | mecca
# Processing Record 11 of Set 11 | ayorou
# Processing Record 12 of Set 11 | namtsy
# Processing Record 13 of Set 11 | vero beach
# Processing Record 14 of Set 11 | manuk mangkaw
# Processing Record 15 of Set 11 | nurota
# Processing Record 16 of Set 11 | kabwe
# Processing Record 17 of Set 11 | mehamn
# Processing Record 18 of Set 11 | chicama
# Processing Record 19 of Set 11 | taltal
# Processing Record 20 of Set 11 | lujan
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | san juan de uraba
# Processing Record 23 of Set 11 | atasu
# Processing Record 24 of Set 11 | acarau
# Processing Record 25 of Set 11 | zhovti vody
# Processing Record 26 of Set 11 | prince george
# Processing Record 27 of Set 11 | effingham
# Processing Record 28 of Set 11 | blackwater
# Processing Record 29 of Set 11 | thunder bay
# Processing Record 30 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 31 of Set 11 | mokhotlong
# Processing Record 32 of Set 11 | kedrovyy
# Processing Record 33 of Set 11 | stornoway
# Processing Record 34 of Set 11 | xuddur
# Processing Record 35 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 11 | butembo
# Processing Record 37 of Set 11 | palafrugell
# Processing Record 38 of Set 11 | port hardy
# Processing Record 39 of Set 11 | shimoda
# Processing Record 40 of Set 11 | mehran
# Processing Record 41 of Set 11 | odweyne
# Processing Record 42 of Set 11 | virginia beach
# Processing Record 43 of Set 11 | maningrida
# Processing Record 44 of Set 11 | aksarka
# Processing Record 45 of Set 11 | gravdal
# Processing Record 46 of Set 11 | sarkand
# Processing Record 47 of Set 11 | moose factory
# Processing Record 48 of Set 11 | christchurch
# Processing Record 49 of Set 11 | bangassou
# Processing Record 50 of Set 11 | cherskiy
# Processing Record 1 of Set 12 | bilibino
# Processing Record 2 of Set 12 | mayo
# Processing Record 3 of Set 12 | parabel
# Processing Record 4 of Set 12 | jambi
# Processing Record 5 of Set 12 | feodosiya
# Processing Record 6 of Set 12 | valdosta
# Processing Record 7 of Set 12 | quatre cocos
# Processing Record 8 of Set 12 | bulgan
# Processing Record 9 of Set 12 | antsla
# Processing Record 10 of Set 12 | hualmay
# Processing Record 11 of Set 12 | timmins
# Processing Record 12 of Set 12 | hambantota
# Processing Record 13 of Set 12 | koumac
# Processing Record 14 of Set 12 | takob
# City not found. Skipping...
# Processing Record 15 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 16 of Set 12 | kirensk
# Processing Record 17 of Set 12 | hirara
# Processing Record 18 of Set 12 | muravlenko
# Processing Record 19 of Set 12 | igarka
# Processing Record 20 of Set 12 | concordia
# Processing Record 21 of Set 12 | sitka
# Processing Record 22 of Set 12 | boyolangu
# Processing Record 23 of Set 12 | novo aripuana
# Processing Record 24 of Set 12 | jishou
# Processing Record 25 of Set 12 | ystad
# Processing Record 26 of Set 12 | usinsk
# Processing Record 27 of Set 12 | road town
# Processing Record 28 of Set 12 | rehoboth
# Processing Record 29 of Set 12 | padang
# Processing Record 30 of Set 12 | sovetskiy
# Processing Record 31 of Set 12 | verkhnyaya inta
# Processing Record 32 of Set 12 | san jeronimo
# Processing Record 33 of Set 12 | denpasar
# Processing Record 34 of Set 12 | lopsmarka
# Processing Record 35 of Set 12 | lewisporte
# Processing Record 36 of Set 12 | yar-sale
# Processing Record 37 of Set 12 | shaowu
# Processing Record 38 of Set 12 | ulaangom
# Processing Record 39 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 12 | saint-joseph
# Processing Record 41 of Set 12 | magdagachi
# Processing Record 42 of Set 12 | aras
# Processing Record 43 of Set 12 | olafsvik
# Processing Record 44 of Set 12 | la palma
# Processing Record 45 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 46 of Set 12 | lagoa
# Processing Record 47 of Set 12 | ca mau
# Processing Record 48 of Set 12 | zhangjiakou
# Processing Record 49 of Set 12 | san ramon
# Processing Record 50 of Set 12 | osoyoos
# Processing Record 1 of Set 13 | palu
# Processing Record 2 of Set 13 | puerto leguizamo
# Processing Record 3 of Set 13 | lappeenranta
# Processing Record 4 of Set 13 | poya
# Processing Record 5 of Set 13 | surt
# Processing Record 6 of Set 13 | ibra
# Processing Record 7 of Set 13 | roald
# Processing Record 8 of Set 13 | larsnes
# Processing Record 9 of Set 13 | kaeo
# Processing Record 10 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 13 | homer
# Processing Record 12 of Set 13 | gouyave
# Processing Record 13 of Set 13 | redmond
# Processing Record 14 of Set 13 | brekstad
# Processing Record 15 of Set 13 | port lincoln
# Processing Record 16 of Set 13 | rincon
# Processing Record 17 of Set 13 | axim
# Processing Record 18 of Set 13 | samoylovka
# Processing Record 19 of Set 13 | paso de carrasco
# Processing Record 20 of Set 13 | itapuranga
# Processing Record 21 of Set 13 | gat
# Processing Record 22 of Set 13 | altay
# Processing Record 23 of Set 13 | kenora
# Processing Record 24 of Set 13 | klaksvik
# Processing Record 25 of Set 13 | solnechnyy
# Processing Record 26 of Set 13 | bacolod
# Processing Record 27 of Set 13 | preobrazheniye
# Processing Record 28 of Set 13 | zaysan
# Processing Record 29 of Set 13 | makuyuni
# Processing Record 30 of Set 13 | batagay-alyta
# Processing Record 31 of Set 13 | bahia honda
# Processing Record 32 of Set 13 | dubbo
# Processing Record 33 of Set 13 | ginda
# Processing Record 34 of Set 13 | tabas
# Processing Record 35 of Set 13 | kismayo
# Processing Record 36 of Set 13 | aplahoue
# Processing Record 37 of Set 13 | grenfell
# Processing Record 38 of Set 13 | yauya
# Processing Record 39 of Set 13 | sheboygan
# Processing Record 40 of Set 13 | sohag
# Processing Record 41 of Set 13 | gizo
# Processing Record 42 of Set 13 | bohodukhiv
# Processing Record 43 of Set 13 | deming
# Processing Record 44 of Set 13 | guatire
# Processing Record 45 of Set 13 | vestmanna
# Processing Record 46 of Set 13 | marzuq
# Processing Record 47 of Set 13 | san cristobal
# Processing Record 48 of Set 13 | bauchi
# Processing Record 49 of Set 13 | cervo
# Processing Record 50 of Set 13 | barranquilla
# Processing Record 1 of Set 14 | ushtobe
# Processing Record 2 of Set 14 | xichang
# Processing Record 3 of Set 14 | turtas
# Processing Record 4 of Set 14 | beloha
# Processing Record 5 of Set 14 | ponta delgada
# Processing Record 6 of Set 14 | chabahar
# Processing Record 7 of Set 14 | pangody
# Processing Record 8 of Set 14 | bexhill
# Processing Record 9 of Set 14 | galion
# Processing Record 10 of Set 14 | noumea
# Processing Record 11 of Set 14 | atambua
# Processing Record 12 of Set 14 | miri
# Processing Record 13 of Set 14 | amarante do maranhao
# Processing Record 14 of Set 14 | mataram
# Processing Record 15 of Set 14 | sheridan
# Processing Record 16 of Set 14 | meulaboh
# Processing Record 17 of Set 14 | abonnema
# Processing Record 18 of Set 14 | burns lake
# Processing Record 19 of Set 14 | grand gaube
# Processing Record 20 of Set 14 | mogadishu
# Processing Record 21 of Set 14 | banda aceh
# Processing Record 22 of Set 14 | humlebaek
# Processing Record 23 of Set 14 | dickinson
# Processing Record 24 of Set 14 | arlit
# Processing Record 25 of Set 14 | peniche
# Processing Record 26 of Set 14 | komsomolskiy
# Processing Record 27 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 28 of Set 14 | epiniana
# Processing Record 29 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 14 | poum
# Processing Record 31 of Set 14 | ladovskaya balka
# Processing Record 32 of Set 14 | aklavik
# Processing Record 33 of Set 14 | kashi
# Processing Record 34 of Set 14 | novooleksiyivka
# Processing Record 35 of Set 14 | dubti
# Processing Record 36 of Set 14 | matabungkay
# Processing Record 37 of Set 14 | bojonegoro
# Processing Record 38 of Set 14 | kuching
# Processing Record 39 of Set 14 | can
# Processing Record 40 of Set 14 | tirat karmel
# Processing Record 41 of Set 14 | azuqueca de henares
# Processing Record 42 of Set 14 | corinto
# Processing Record 43 of Set 14 | juba
# Processing Record 44 of Set 14 | baton rouge
# Processing Record 45 of Set 14 | kaka
# Processing Record 46 of Set 14 | tukrah
# Processing Record 47 of Set 14 | kamyshlov
# Processing Record 48 of Set 14 | plymouth
# Processing Record 49 of Set 14 | yangambi
# Processing Record 50 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 15 | garm
# City not found. Skipping...
# Processing Record 3 of Set 15 | long beach
# Processing Record 4 of Set 15 | raudeberg
# Processing Record 5 of Set 15 | lashio
# Processing Record 6 of Set 15 | broken hill
# Processing Record 7 of Set 15 | port shepstone
# Processing Record 8 of Set 15 | vila franca do campo
# Processing Record 9 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 15 | pontes e lacerda
# Processing Record 11 of Set 15 | mihaesti
# Processing Record 12 of Set 15 | trincomalee
# Processing Record 13 of Set 15 | qasigiannguit
# Processing Record 14 of Set 15 | tupik
# Processing Record 15 of Set 15 | jutai
# Processing Record 16 of Set 15 | abaete
# Processing Record 17 of Set 15 | abapo
# Processing Record 18 of Set 15 | pingliang
# Processing Record 19 of Set 15 | jumla
# Processing Record 20 of Set 15 | kyaikkami
# Processing Record 21 of Set 15 | nokaneng
# Processing Record 22 of Set 15 | samarai
# Processing Record 23 of Set 15 | silva jardim
# Processing Record 24 of Set 15 | banmankhi
# Processing Record 25 of Set 15 | gobabis
# Processing Record 26 of Set 15 | tuy hoa
# Processing Record 27 of Set 15 | nicoya
# Processing Record 28 of Set 15 | thai binh
# Processing Record 29 of Set 15 | puerto maldonado
# Processing Record 30 of Set 15 | lichinga
# Processing Record 31 of Set 15 | charagua
# Processing Record 32 of Set 15 | maumere
# Processing Record 33 of Set 15 | tomatlan
# Processing Record 34 of Set 15 | tigil
# Processing Record 35 of Set 15 | charters towers
# Processing Record 36 of Set 15 | taywarah
# Processing Record 37 of Set 15 | midyat
# Processing Record 38 of Set 15 | dover
# Processing Record 39 of Set 15 | yilan
# Processing Record 40 of Set 15 | koregaon
# Processing Record 41 of Set 15 | koygorodok
# Processing Record 42 of Set 15 | palaia fokaia
# Processing Record 43 of Set 15 | mantua
# Processing Record 44 of Set 15 | sukhumi
# Processing Record 45 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 15 | brae
# Processing Record 47 of Set 15 | kanniyakumari
# Processing Record 48 of Set 15 | sangar
# Processing Record 49 of Set 15 | katha
# City not found. Skipping...
# Processing Record 50 of Set 15 | naryan-mar
# Processing Record 1 of Set 16 | belaya gora
# Processing Record 2 of Set 16 | beppu
# Processing Record 3 of Set 16 | aswan
# Processing Record 4 of Set 16 | washougal
# Processing Record 5 of Set 16 | puerto carreno
# Processing Record 6 of Set 16 | ribeira brava
# Processing Record 7 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 16 | severodvinsk
# Processing Record 9 of Set 16 | parana
# Processing Record 10 of Set 16 | contai
# Processing Record 11 of Set 16 | mikhaylovka
# Processing Record 12 of Set 16 | farafangana
# Processing Record 13 of Set 16 | ruteng
# Processing Record 14 of Set 16 | brookings
# Processing Record 15 of Set 16 | tynda
# Processing Record 16 of Set 16 | alyangula
# Processing Record 17 of Set 16 | uroteppa
# City not found. Skipping...
# Processing Record 18 of Set 16 | matara
# Processing Record 19 of Set 16 | shirokiy
# Processing Record 20 of Set 16 | jubayl
# City not found. Skipping...
# Processing Record 21 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 16 | pudozh
# Processing Record 23 of Set 16 | zaltbommel
# Processing Record 24 of Set 16 | mount isa
# Processing Record 25 of Set 16 | challapata
# Processing Record 26 of Set 16 | gannan
# Processing Record 27 of Set 16 | salta
# Processing Record 28 of Set 16 | omboue
# Processing Record 29 of Set 16 | launceston
# Processing Record 30 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 16 | chepareria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 718

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Harper      LR   4.3750   -7.7169     80.02        86
# 1             Hasaki      JP  35.7333  140.8333     66.00        39
# 2  São João da Barra      BR -21.6403  -41.0511     67.44        88
# 3               Paka      MY   4.6374  103.4368     86.00        74
# 4             Castro      BR -24.7911  -50.0119     51.08        95
# 5       Puerto Ayora      EC  -0.7393  -90.3518     77.00        95
# 6              Kapaa      US  22.0752 -159.3190     78.80        69
# 7             Avarua      CK -21.2078 -159.7750     78.80        78
# 8            Rikitea      PF -23.1203 -134.9692     77.92        78
# 9           Bengkulu      ID  -3.8004  102.2655     83.01        63
#
#    Cloudiness  Wind Speed Current Description
# 0         100        6.40     overcast clouds
# 1          20       14.97          few clouds
# 2           0        9.19           clear sky
# 3          20        3.44          few clouds
# 4          22        2.46          few clouds
# 5          44        3.00    scattered clouds
# 6          40        8.05    scattered clouds
# 7          75       12.66       broken clouds
# 8         100       14.05          light rain
# 9          63        4.38       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
