# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather Map API Call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high = 90.000, size =2000)
lngs = np.random.uniform(low= -180.000, high =180.000, size =2000)

lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

print(coordinates)
# Out:
# [(-17.108955303173317, 60.37929058651261), (43.47975451321807, 32.54679782045076), (40.27011419424582, 60.16604536005366), (-85.51828547190601, 153.92714827263524), (-19.44631052201889, -75.62175592687666), (21.90369610624076, -36.32834868070685), (32.748440980426025, 20.169306625436036), (-74.41126905353984, 42.78074699538868), (-84.88096789570793, -96.93566538793266), (-65.88749245786988, -0.6684999094381965), (-75.04318847914077, -145.86842549197146), (-0.4120161846298913, -40.22020164157789), (65.30808297843035, -157.01512108194598), (-61.616411811628936, 27.039155666815304), (0.9968204143674768, 117.19309951491488), (-44.116824069959456, -23.588180521497776), (66.90522789020957, 63.63922738139476), (18.383830776392287, 75.219740405361), (-74.0484601247824, -167.67789930464156), (-43.728436533158245, -160.2744415869289), (-89.91764460036597, -158.25917674751457), (44.566921109161086, 82.65655576607139), (-53.19258955944545, -3.0158913135889804), (-3.4253027073048514, 41.14303133370254), (-2.275888535831484, -91.65106503140973), (-7.788250462031257, 118.49895259127965), (-28.197457613788472, -47.285324305152955), (49.26454912821319, 146.18481844340636), (-88.8066373430079, -19.322571927458966), (-49.88983630399419, 63.25019133450027), (-29.83862876710357, 3.2246915495264545), (-48.82111382353253, 14.235805011814506), (28.390752095537863, 87.82675172560977), (71.81165335907215, -83.5251237884145), (-84.67204929148066, -170.98443682209555), (21.814030427731353, 59.34857806086964), (89.51408214715042, 54.116789686846715), (17.652383307016322, -20.452642206347633), (58.25784270375098, 154.80780078577573), (49.06883451238815, -45.273277134175345), (-53.58462145959417, 45.15003782807463), (22.169406928908757, 107.17834709387557), (67.64203910420244, 72.67979895702135), (-8.387425108574476, 171.67420612708383), (-16.994040216739492, -173.62211165677965), (61.08482192917927, -75.3245411150093), (-6.596761519662309, 73.63585320544962), (-47.12067454623565, 153.94082096331448), (19.37166570809326, -64.70588304445958), (-28.355753407999835, -18.084679181190126), (-6.370829290449535, 58.8774874381545), (-58.922945886075645, -13.170860385348305), (-60.96693733360374, 91.55878175969377), (5.21385812876656, -1.5677332991586752), (72.77292095105747, 38.06620744014029), (59.110570345392716, 118.15996455144335), (34.3754305329434, 60.76288115578103), (29.964424426210698, 63.51115310141407), (-77.78584423348006, 5.132898305150633), (-54.89022218787636, 143.62312477677716), (82.07361354514077, -35.91406273391621), (-2.2441360736074785, 77.5231717390896), (-23.260172208359293, -99.61870596077226), (-50.176933682765835, -13.655820388725715), (42.44250553774481, 64.85327787077946), (45.273985146873486, 33.759428307029424), (-28.306537498437386, 143.65047010230438), (38.32991446007608, -81.78031127427079), (-48.494538658868095, -147.50144767418405), (-25.268349856604715, 7.633320232679807), (57.3506859386338, -146.75324249277932), (-24.59073740069087, -87.08329176828481), (-66.13827218939899, 70.4482746384353), (27.941345229881932, 33.31331207814367), (65.60102191147487, 50.12521898911933), (-57.87334963964246, 122.08581997329946), (-72.26768111557786, 126.0694168134678), (-66.63759278517405, 110.6094391229708), (62.76524837966434, -100.12842861814754), (-85.83419891516643, 135.0749527099502), (76.94019534063071, 94.7278918722227), (-54.68001477595305, 136.2058624452547), (-56.210423303108726, 21.634925740771166), (85.87636274495381, -86.46789624965005), (1.8573067747184808, 25.00357954483445), (45.55055460820955, -102.23011593618), (-51.33202267943081, 5.156051003124901), (-73.425252496545, 95.76363656935666), (15.653050042914003, -11.98605172868983), (-28.479350968825543, 105.62604447228665), (5.1406005520583875, 73.29593752407308), (27.738534167921102, 76.11404529102339), (-89.0467312815402, 142.43969979443426), (-88.3105023177919, -118.7231166778208), (-59.452519482708205, -135.9412452546485), (-38.43328846329541, 139.7688693046091), (-6.67953 ...

# %%
# Get the nearest city using citipy

from citipy import citipy

# Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combiantion.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
print(cities)
# Out:
# ['grand gaube', 'katsiveli', 'hazorasp', 'bluff', 'camana', 'ponta do sol', 'tukrah', 'port alfred', 'punta arenas', 'cape town', 'mataura', 'acarau', 'barrow', 'kruisfontein', 'bontang', 'arraial do cabo', 'yeletskiy', 'karmala', 'vaini', 'avarua', 'yining', 'malindi', 'puerto ayora', 'bima', 'imbituba', 'vostok', 'ushuaia', 'saint-philippe', 'luderitz', 'hermanus', 'mangan', 'clyde river', 'sur', 'belushya guba', 'santa maria', 'talaya', 'torbay', 'east london', 'lang son', 'staryy nadym', 'lolua', 'hihifo', 'iqaluit', 'hithadhoo', 'hobart', 'road town', 'jamestown', 'victoria', 'busselton', 'shama', 'tumannyy', 'chara', 'taybad', 'rudbar', 'tasiilaq', 'nurota', 'pervomayskoye', 'broken hill', 'saint albans', 'walvis bay', 'palmer', 'marcona', 'hurghada', 'ust-tsilma', 'albany', 'new norfolk', 'thompson', 'khatanga', 'bredasdorp', 'qaanaaq', 'buta', 'dickinson', 'maghama', 'carnarvon', 'eydhafushi', 'kot putli', 'rikitea', 'mount gambier', 'cabedelo', 'achisay', 'nanortalik', 'chodavaram', 'atuona', 'lebu', 'faqirwali', 'bababe', 'lorengau', 'dunedin', 'booue', 'acapulco', 'presidencia roque saenz pena', 'khani', 'kapaa', 'biak', 'sentyabrskiy', 'camacha', 'kuching', 'karratha', 'kolosovka', 'abu dhabi', 'pishva', 'rosetta', 'dikson', 'kropotkin', 'tiksi', 'mahebourg', 'nouadhibou', 'sosnovka', 'taolanaro', 'cabo san lucas', 'illoqqortoormiut', 'vanimo', 'strezhevoy', 'barentsburg', 'le port', 'sesheke', 'yinchuan', 'broome', 'vangaindrano', 'cherskiy', 'mys shmidta', 'vila velha', 'grindavik', 'kulhudhuffushi', 'mitsamiouli', 'qasigiannguit', 'isla vista', 'oxbow', 'lashio', 'georgetown', 'moscow', 'tuktoyaktuk', 'saldanha', 'rocha', 'teya', 'naze', 'pemberton', 'ilulissat', 'amderma', 'chilca', 'ahipara', 'abengourou', 'khandyga', 'xining', 'talnakh', 'palabuhanratu', 'havre-saint-pierre', 'mrirt', 'whitianga', 'faanui', 'attawapiskat', 'marstal', 'caravelas', 'pisco', 'fonte boa', 'souillac', 'tezu', 'kaitangata', 'yulara', 'abu samrah', 'tsihombe', 'nago', 'henties bay', 'umzimvubu', 'mar del plata', 'lompoc', 'lavrentiya', 'bilma', 'iquique', 'fukue', 'salalah', 'necochea', 'soto la marina', 'thunder bay', 'rabo de peixe', 'khonuu', 'weligama', 'ratnagiri', 'boende', 'umm kaddadah', 'butaritari', 'pak phanang', 'villazon', 'aksehir', 'mazara del vallo', 'nioro', 'burns lake', 'kaa-khem', 'segezha', 'zyryanka', 'narsaq', 'adrar', 'kabardinka', 'chokurdakh', 'erenhot', 'lakselv', 'leningradskiy', 'tuatapere', 'plettenberg bay', 'bathsheba', 'saskylakh', 'ribeira grande', 'manoel urbano', 'darhan', 'tabou', 'tual', 'hobyo', 'fernley', 'algeciras', 'ayagoz', 'zaykovo', 'surt', 'kamaishi', 'fortuna', 'beringovskiy', 'tawau', 'along', 'abadan', 'hilo', 'polovinnoye', 'longyearbyen', 'russell', 'bethel', 'flinders', 'bereznik', 'san quintin', 'tabuk', 'maralal', 'kozhva', 'hasaki', 'castro', 'ouadda', 'yellowknife', 'comodoro rivadavia', 'sayat', 'zhanaozen', 'korla', 'san patricio', 'qaqortoq', 'mecca', 'labuhan', 'robertsport', 'kifri', 'bambous virieux', 'ixtapa', 'hewitt', 'timbiqui', 'satka', 'port elizabeth', 'stubbekobing', 'douentza', 'katsuura', 'ganzhou', 'hami', 'ilinskaya', 'shelburne', 'samarai', 'oil city', 'bur gabo', 'santa rita', 'punta alta', 'dicabisagan', 'pochutla', 'sandwick', 'coquimbo', 'griffith', 'laela', 'barsi', 'zaragoza', 'santa isabel', 'gizo', 'karaman', 'sibolga', 'oksfjord', 'upernavik', 'omboue', 'sterling', 'cidreira', 'suntar', 'curaca', 'fort nelson', 'vice', 'emerald', 'lagoa', 'perth', 'cedar rapids', 'kelvington', 'sobolevo', 'mount darwin', 'wanaka', 'thap than', 'verkhoyansk', 'brae', 'hamilton', 'chingirlau', 'grand river south east', 'tapaua', 'polyarnyy', 'skiros', 'japura', 'weihe', 'puerto el triunfo', 'guayata', 'petropavlovsk-kamchatskiy', 'jalu', 'noyabrsk', 'kishtwar', 'gangotri', 'leh', 'aflu', 'balkanabat', 'saint george', 'bengkulu', 'port-gentil', 'kirensk', 'pitimbu', 'ruatoria', 'kang', 'hunza', 'chuy', 'berbera', 'los llanos de aridane', 'kampot', 'voyvozh', 'nizhneyan ...

# %%
# Declare an empty list to hold the weather data
city_data =[]

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create counterss for the record numbers 1-50 and the set counter
record_count =1
set_count =1

# Instead of using two for loops, we can use the enumerate() method as an alternative way 
# to iterate through the list of cities
# and retrieve both the index, and the city from the list.
# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_city=city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
       
       
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                  "Country": city_country,
                  "Lat": city_lat,      
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | grand gaube
# Processing Record 2 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 1 | hazorasp
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | camana
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | tukrah
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | acarau
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | bontang
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | yeletskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | karmala
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | yining
# Processing Record 22 of Set 1 | malindi
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | bima
# Processing Record 25 of Set 1 | imbituba
# Processing Record 26 of Set 1 | vostok
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | luderitz
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | mangan
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | sur
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | santa maria
# Processing Record 36 of Set 1 | talaya
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | lang son
# Processing Record 40 of Set 1 | staryy nadym
# Processing Record 41 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | road town
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | shama
# Processing Record 1 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 2 | chara
# Processing Record 3 of Set 2 | taybad
# Processing Record 4 of Set 2 | rudbar
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | nurota
# Processing Record 7 of Set 2 | pervomayskoye
# Processing Record 8 of Set 2 | broken hill
# Processing Record 9 of Set 2 | saint albans
# Processing Record 10 of Set 2 | walvis bay
# Processing Record 11 of Set 2 | palmer
# Processing Record 12 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 2 | hurghada
# Processing Record 14 of Set 2 | ust-tsilma
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | buta
# Processing Record 22 of Set 2 | dickinson
# Processing Record 23 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | eydhafushi
# Processing Record 26 of Set 2 | kot putli
# City not found. Skipping...
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | mount gambier
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | chodavaram
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | faqirwali
# Processing Record 36 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | dunedin
# Processing Record 39 of Set 2 | booue
# Processing Record 40 of Set 2 | acapulco
# Processing Record 41 of Set 2 | presidencia roque saenz pena
# Processing Record 42 of Set 2 | khani
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | biak
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | camacha
# Processing Record 47 of Set 2 | kuching
# Processing Record 48 of Set 2 | karratha
# Processing Record 49 of Set 2 | kolosovka
# Processing Record 50 of Set 2 | abu dhabi
# Processing Record 1 of Set 3 | pishva
# Processing Record 2 of Set 3 | rosetta
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | kropotkin
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | nouadhibou
# Processing Record 8 of Set 3 | sosnovka
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | vanimo
# Processing Record 13 of Set 3 | strezhevoy
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | le port
# Processing Record 16 of Set 3 | sesheke
# Processing Record 17 of Set 3 | yinchuan
# Processing Record 18 of Set 3 | broome
# Processing Record 19 of Set 3 | vangaindrano
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | vila velha
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | kulhudhuffushi
# Processing Record 25 of Set 3 | mitsamiouli
# Processing Record 26 of Set 3 | qasigiannguit
# Processing Record 27 of Set 3 | isla vista
# Processing Record 28 of Set 3 | oxbow
# Processing Record 29 of Set 3 | lashio
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | moscow
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | rocha
# Processing Record 35 of Set 3 | teya
# Processing Record 36 of Set 3 | naze
# Processing Record 37 of Set 3 | pemberton
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | chilca
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | abengourou
# Processing Record 43 of Set 3 | khandyga
# Processing Record 44 of Set 3 | xining
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 3 | havre-saint-pierre
# Processing Record 48 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 3 | whitianga
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | marstal
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | fonte boa
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | tezu
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | abu samrah
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | nago
# Processing Record 13 of Set 4 | henties bay
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | bilma
# Processing Record 19 of Set 4 | iquique
# Processing Record 20 of Set 4 | fukue
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | soto la marina
# Processing Record 24 of Set 4 | thunder bay
# Processing Record 25 of Set 4 | rabo de peixe
# Processing Record 26 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 4 | weligama
# Processing Record 28 of Set 4 | ratnagiri
# Processing Record 29 of Set 4 | boende
# Processing Record 30 of Set 4 | umm kaddadah
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | pak phanang
# Processing Record 33 of Set 4 | villazon
# Processing Record 34 of Set 4 | aksehir
# Processing Record 35 of Set 4 | mazara del vallo
# Processing Record 36 of Set 4 | nioro
# Processing Record 37 of Set 4 | burns lake
# Processing Record 38 of Set 4 | kaa-khem
# Processing Record 39 of Set 4 | segezha
# Processing Record 40 of Set 4 | zyryanka
# Processing Record 41 of Set 4 | narsaq
# Processing Record 42 of Set 4 | adrar
# Processing Record 43 of Set 4 | kabardinka
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | erenhot
# Processing Record 46 of Set 4 | lakselv
# Processing Record 47 of Set 4 | leningradskiy
# Processing Record 48 of Set 4 | tuatapere
# Processing Record 49 of Set 4 | plettenberg bay
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | manoel urbano
# Processing Record 4 of Set 5 | darhan
# Processing Record 5 of Set 5 | tabou
# Processing Record 6 of Set 5 | tual
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | fernley
# Processing Record 9 of Set 5 | algeciras
# Processing Record 10 of Set 5 | ayagoz
# Processing Record 11 of Set 5 | zaykovo
# Processing Record 12 of Set 5 | surt
# Processing Record 13 of Set 5 | kamaishi
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | beringovskiy
# Processing Record 16 of Set 5 | tawau
# Processing Record 17 of Set 5 | along
# Processing Record 18 of Set 5 | abadan
# Processing Record 19 of Set 5 | hilo
# Processing Record 20 of Set 5 | polovinnoye
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | russell
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | flinders
# Processing Record 25 of Set 5 | bereznik
# Processing Record 26 of Set 5 | san quintin
# Processing Record 27 of Set 5 | tabuk
# Processing Record 28 of Set 5 | maralal
# Processing Record 29 of Set 5 | kozhva
# Processing Record 30 of Set 5 | hasaki
# Processing Record 31 of Set 5 | castro
# Processing Record 32 of Set 5 | ouadda
# Processing Record 33 of Set 5 | yellowknife
# Processing Record 34 of Set 5 | comodoro rivadavia
# Processing Record 35 of Set 5 | sayat
# Processing Record 36 of Set 5 | zhanaozen
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | qaqortoq
# Processing Record 40 of Set 5 | mecca
# Processing Record 41 of Set 5 | labuhan
# Processing Record 42 of Set 5 | robertsport
# Processing Record 43 of Set 5 | kifri
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | ixtapa
# Processing Record 46 of Set 5 | hewitt
# Processing Record 47 of Set 5 | timbiqui
# Processing Record 48 of Set 5 | satka
# Processing Record 49 of Set 5 | port elizabeth
# Processing Record 50 of Set 5 | stubbekobing
# Processing Record 1 of Set 6 | douentza
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | ganzhou
# Processing Record 4 of Set 6 | hami
# Processing Record 5 of Set 6 | ilinskaya
# Processing Record 6 of Set 6 | shelburne
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | oil city
# Processing Record 9 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 6 | santa rita
# Processing Record 11 of Set 6 | punta alta
# Processing Record 12 of Set 6 | dicabisagan
# Processing Record 13 of Set 6 | pochutla
# Processing Record 14 of Set 6 | sandwick
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | griffith
# Processing Record 17 of Set 6 | laela
# Processing Record 18 of Set 6 | barsi
# Processing Record 19 of Set 6 | zaragoza
# Processing Record 20 of Set 6 | santa isabel
# Processing Record 21 of Set 6 | gizo
# Processing Record 22 of Set 6 | karaman
# Processing Record 23 of Set 6 | sibolga
# Processing Record 24 of Set 6 | oksfjord
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | omboue
# Processing Record 27 of Set 6 | sterling
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | suntar
# Processing Record 30 of Set 6 | curaca
# Processing Record 31 of Set 6 | fort nelson
# Processing Record 32 of Set 6 | vice
# Processing Record 33 of Set 6 | emerald
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | perth
# Processing Record 36 of Set 6 | cedar rapids
# Processing Record 37 of Set 6 | kelvington
# Processing Record 38 of Set 6 | sobolevo
# Processing Record 39 of Set 6 | mount darwin
# Processing Record 40 of Set 6 | wanaka
# Processing Record 41 of Set 6 | thap than
# Processing Record 42 of Set 6 | verkhoyansk
# Processing Record 43 of Set 6 | brae
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | chingirlau
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 6 | polyarnyy
# Processing Record 49 of Set 6 | skiros
# City not found. Skipping...
# Processing Record 50 of Set 6 | japura
# Processing Record 1 of Set 7 | weihe
# Processing Record 2 of Set 7 | puerto el triunfo
# Processing Record 3 of Set 7 | guayata
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | jalu
# Processing Record 6 of Set 7 | noyabrsk
# Processing Record 7 of Set 7 | kishtwar
# Processing Record 8 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 7 | leh
# Processing Record 10 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 7 | balkanabat
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | kirensk
# Processing Record 16 of Set 7 | pitimbu
# Processing Record 17 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 7 | kang
# Processing Record 19 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 7 | chuy
# Processing Record 21 of Set 7 | berbera
# Processing Record 22 of Set 7 | los llanos de aridane
# Processing Record 23 of Set 7 | kampot
# Processing Record 24 of Set 7 | voyvozh
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | viedma
# Processing Record 27 of Set 7 | waipawa
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | turukhansk
# Processing Record 30 of Set 7 | katangli
# Processing Record 31 of Set 7 | camocim
# Processing Record 32 of Set 7 | stykkisholmur
# Processing Record 33 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 7 | dongying
# Processing Record 35 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 7 | skelleftea
# Processing Record 37 of Set 7 | nouakchott
# Processing Record 38 of Set 7 | zhuhai
# Processing Record 39 of Set 7 | la ronge
# Processing Record 40 of Set 7 | avera
# Processing Record 41 of Set 7 | celestun
# Processing Record 42 of Set 7 | hyeres
# Processing Record 43 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 44 of Set 7 | laguna
# Processing Record 45 of Set 7 | oriximina
# Processing Record 46 of Set 7 | shevchenkove
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | marfino
# Processing Record 50 of Set 7 | champasak
# Processing Record 1 of Set 8 | port macquarie
# Processing Record 2 of Set 8 | alice springs
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | pangoa
# Processing Record 5 of Set 8 | derzhavinsk
# Processing Record 6 of Set 8 | pulandian
# Processing Record 7 of Set 8 | ust-kuyga
# Processing Record 8 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 8 | sonneberg
# Processing Record 10 of Set 8 | badarwas
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | ponta delgada
# Processing Record 13 of Set 8 | mordovo
# Processing Record 14 of Set 8 | borodino
# Processing Record 15 of Set 8 | kudat
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | alberton
# Processing Record 18 of Set 8 | sao filipe
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 8 | port blair
# Processing Record 23 of Set 8 | iseyin
# Processing Record 24 of Set 8 | palu
# Processing Record 25 of Set 8 | port hardy
# Processing Record 26 of Set 8 | vallenar
# Processing Record 27 of Set 8 | borogontsy
# Processing Record 28 of Set 8 | katete
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | itaituba
# Processing Record 31 of Set 8 | porto novo
# Processing Record 32 of Set 8 | jibuti
# Processing Record 33 of Set 8 | hirara
# Processing Record 34 of Set 8 | parrita
# Processing Record 35 of Set 8 | boden
# Processing Record 36 of Set 8 | kurumkan
# Processing Record 37 of Set 8 | kahului
# Processing Record 38 of Set 8 | kodiak
# Processing Record 39 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 8 | kaduqli
# Processing Record 41 of Set 8 | edgewater
# Processing Record 42 of Set 8 | rath
# Processing Record 43 of Set 8 | puerto escondido
# Processing Record 44 of Set 8 | mandal
# Processing Record 45 of Set 8 | yenagoa
# Processing Record 46 of Set 8 | husavik
# Processing Record 47 of Set 8 | severo-kurilsk
# Processing Record 48 of Set 8 | fare
# Processing Record 49 of Set 8 | charters towers
# Processing Record 50 of Set 8 | amboise
# Processing Record 1 of Set 9 | rock sound
# Processing Record 2 of Set 9 | lamar
# Processing Record 3 of Set 9 | smolenka
# Processing Record 4 of Set 9 | baruun-urt
# Processing Record 5 of Set 9 | nilanga
# Processing Record 6 of Set 9 | praia
# Processing Record 7 of Set 9 | bonavista
# Processing Record 8 of Set 9 | konosha
# Processing Record 9 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 10 of Set 9 | fairmont
# Processing Record 11 of Set 9 | touros
# Processing Record 12 of Set 9 | plattsburgh
# Processing Record 13 of Set 9 | islamkot
# Processing Record 14 of Set 9 | jaque
# Processing Record 15 of Set 9 | tazovskiy
# Processing Record 16 of Set 9 | shelopugino
# Processing Record 17 of Set 9 | mongar
# Processing Record 18 of Set 9 | inhambane
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | pevek
# Processing Record 21 of Set 9 | lebanon
# Processing Record 22 of Set 9 | miranda
# Processing Record 23 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 24 of Set 9 | wanning
# Processing Record 25 of Set 9 | namwala
# Processing Record 26 of Set 9 | opuwo
# Processing Record 27 of Set 9 | bairnsdale
# Processing Record 28 of Set 9 | cambui
# Processing Record 29 of Set 9 | ostrovnoy
# Processing Record 30 of Set 9 | bairiki
# Processing Record 31 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 9 | alta floresta
# Processing Record 33 of Set 9 | sorong
# Processing Record 34 of Set 9 | varkaus
# Processing Record 35 of Set 9 | waingapu
# Processing Record 36 of Set 9 | canon city
# Processing Record 37 of Set 9 | grand island
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | meulaboh
# Processing Record 40 of Set 9 | yala
# Processing Record 41 of Set 9 | rincon
# Processing Record 42 of Set 9 | hofn
# Processing Record 43 of Set 9 | gualaceo
# Processing Record 44 of Set 9 | batsfjord
# Processing Record 45 of Set 9 | newport
# Processing Record 46 of Set 9 | odweyne
# Processing Record 47 of Set 9 | mayumba
# Processing Record 48 of Set 9 | bacolod
# Processing Record 49 of Set 9 | chillicothe
# Processing Record 50 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 1 of Set 10 | yelizovo
# Processing Record 2 of Set 10 | arkhangelsk
# Processing Record 3 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 10 | nikolskoye
# Processing Record 6 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 10 | humaita
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | taoudenni
# Processing Record 10 of Set 10 | mumbwa
# Processing Record 11 of Set 10 | diffa
# Processing Record 12 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 13 of Set 10 | nsanje
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | raudeberg
# Processing Record 16 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 10 | mahibadhoo
# Processing Record 18 of Set 10 | yanam
# Processing Record 19 of Set 10 | soyo
# Processing Record 20 of Set 10 | fairbanks
# Processing Record 21 of Set 10 | curanilahue
# Processing Record 22 of Set 10 | san giuseppe jato
# Processing Record 23 of Set 10 | rio gallegos
# Processing Record 24 of Set 10 | vila franca do campo
# Processing Record 25 of Set 10 | tongliao
# Processing Record 26 of Set 10 | eyl
# Processing Record 27 of Set 10 | san cristobal
# Processing Record 28 of Set 10 | puerto colombia
# Processing Record 29 of Set 10 | consuegra
# Processing Record 30 of Set 10 | uetze
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | puerto narino
# Processing Record 33 of Set 10 | trinidad
# Processing Record 34 of Set 10 | douglas
# Processing Record 35 of Set 10 | pozzallo
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | kovdor
# Processing Record 38 of Set 10 | maldonado
# Processing Record 39 of Set 10 | kilembe
# Processing Record 40 of Set 10 | winslow
# Processing Record 41 of Set 10 | egvekinot
# Processing Record 42 of Set 10 | guerrero negro
# Processing Record 43 of Set 10 | hammerfest
# Processing Record 44 of Set 10 | sorland
# Processing Record 45 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 10 | tessalit
# Processing Record 47 of Set 10 | geraldton
# Processing Record 48 of Set 10 | mercedes
# Processing Record 49 of Set 10 | galveston
# Processing Record 50 of Set 10 | sabang
# Processing Record 1 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 2 of Set 11 | naxos
# Processing Record 3 of Set 11 | rio grande
# Processing Record 4 of Set 11 | chipinge
# Processing Record 5 of Set 11 | norman wells
# Processing Record 6 of Set 11 | kenai
# Processing Record 7 of Set 11 | port hedland
# Processing Record 8 of Set 11 | slave lake
# Processing Record 9 of Set 11 | axixa do tocantins
# City not found. Skipping...
# Processing Record 10 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 11 | bubaque
# Processing Record 12 of Set 11 | provideniya
# Processing Record 13 of Set 11 | north bend
# Processing Record 14 of Set 11 | esperance
# Processing Record 15 of Set 11 | najran
# Processing Record 16 of Set 11 | cam ranh
# Processing Record 17 of Set 11 | staunton
# Processing Record 18 of Set 11 | shitanjing
# Processing Record 19 of Set 11 | batemans bay
# Processing Record 20 of Set 11 | lasa
# Processing Record 21 of Set 11 | cradock
# Processing Record 22 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 11 | shelomi
# Processing Record 24 of Set 11 | mackay
# Processing Record 25 of Set 11 | belle fourche
# Processing Record 26 of Set 11 | corralillo
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | puro
# Processing Record 29 of Set 11 | hambantota
# Processing Record 30 of Set 11 | sakaiminato
# Processing Record 31 of Set 11 | sayyan
# Processing Record 32 of Set 11 | doka
# Processing Record 33 of Set 11 | paungde
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | komono
# Processing Record 36 of Set 11 | mende
# Processing Record 37 of Set 11 | sorokino
# Processing Record 38 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 11 | jiuquan
# Processing Record 40 of Set 11 | dolores
# Processing Record 41 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 11 | khatassy
# Processing Record 43 of Set 11 | bobonong
# City not found. Skipping...
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 11 | alofi
# Processing Record 47 of Set 11 | raasiku
# Processing Record 48 of Set 11 | tonantins
# Processing Record 49 of Set 11 | jefferson city
# Processing Record 50 of Set 11 | irondequoit
# Processing Record 1 of Set 12 | basoko
# Processing Record 2 of Set 12 | lithgow
# Processing Record 3 of Set 12 | caldelas
# Processing Record 4 of Set 12 | frankfort
# Processing Record 5 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 12 | taraz
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | bandarbeyla
# Processing Record 9 of Set 12 | hervey bay
# Processing Record 10 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | limoges
# Processing Record 13 of Set 12 | arboletes
# Processing Record 14 of Set 12 | dalvik
# Processing Record 15 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 12 | uray
# Processing Record 17 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | cabudare
# Processing Record 20 of Set 12 | durango
# Processing Record 21 of Set 12 | lumberton
# Processing Record 22 of Set 12 | santa isabel do rio negro
# Processing Record 23 of Set 12 | abramovka
# Processing Record 24 of Set 12 | nemuro
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | hualmay
# Processing Record 27 of Set 12 | mulki
# Processing Record 28 of Set 12 | san joaquin
# Processing Record 29 of Set 12 | ola
# Processing Record 30 of Set 12 | khilchipur
# Processing Record 31 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 12 | dongsheng
# Processing Record 33 of Set 12 | makakilo city
# Processing Record 34 of Set 12 | jiazi
# Processing Record 35 of Set 12 | itarema
# Processing Record 36 of Set 12 | udalguri
# Processing Record 37 of Set 12 | christchurch
# Processing Record 38 of Set 12 | zaplyusye
# City not found. Skipping...
# Processing Record 39 of Set 12 | asfi
# Processing Record 40 of Set 12 | jumilla
# Processing Record 41 of Set 12 | buala
# Processing Record 42 of Set 12 | abonnema
# Processing Record 43 of Set 12 | vestmannaeyjar
# Processing Record 44 of Set 12 | canby
# Processing Record 45 of Set 12 | espanola
# Processing Record 46 of Set 12 | talcahuano
# Processing Record 47 of Set 12 | aklavik
# Processing Record 48 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 12 | oranjemund
# Processing Record 50 of Set 12 | constitucion
# Processing Record 1 of Set 13 | palmas
# Processing Record 2 of Set 13 | sambava
# Processing Record 3 of Set 13 | owosso
# Processing Record 4 of Set 13 | ivanteyevka
# Processing Record 5 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 13 | ler
# Processing Record 7 of Set 13 | saint anthony
# Processing Record 8 of Set 13 | cruzeiro do oeste
# Processing Record 9 of Set 13 | jamkhandi
# Processing Record 10 of Set 13 | qurayyat
# Processing Record 11 of Set 13 | marsa matruh
# Processing Record 12 of Set 13 | burica
# City not found. Skipping...
# Processing Record 13 of Set 13 | karabanovo
# Processing Record 14 of Set 13 | ornes
# Processing Record 15 of Set 13 | namibe
# Processing Record 16 of Set 13 | paranaiba
# Processing Record 17 of Set 13 | beyneu
# Processing Record 18 of Set 13 | gravdal
# Processing Record 19 of Set 13 | nove straseci
# Processing Record 20 of Set 13 | caranavi
# Processing Record 21 of Set 13 | tecoanapa
# Processing Record 22 of Set 13 | turochak
# Processing Record 23 of Set 13 | nyurba
# Processing Record 24 of Set 13 | porto de moz
# Processing Record 25 of Set 13 | eidsvag
# Processing Record 26 of Set 13 | almeirim
# Processing Record 27 of Set 13 | tarko-sale
# Processing Record 28 of Set 13 | bon accord
# Processing Record 29 of Set 13 | quchan
# Processing Record 30 of Set 13 | helong
# Processing Record 31 of Set 13 | port hueneme
# Processing Record 32 of Set 13 | manzhouli
# Processing Record 33 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 34 of Set 13 | marion
# Processing Record 35 of Set 13 | urumqi
# Processing Record 36 of Set 13 | yaan
# Processing Record 37 of Set 13 | qui nhon
# Processing Record 38 of Set 13 | brownsville
# Processing Record 39 of Set 13 | arcata
# Processing Record 40 of Set 13 | sarandi
# Processing Record 41 of Set 13 | high level
# Processing Record 42 of Set 13 | tromso
# Processing Record 43 of Set 13 | pangody
# Processing Record 44 of Set 13 | tera
# Processing Record 45 of Set 13 | nome
# Processing Record 46 of Set 13 | zhigansk
# Processing Record 47 of Set 13 | port lincoln
# Processing Record 48 of Set 13 | davila
# Processing Record 49 of Set 13 | biri
# Processing Record 50 of Set 13 | chulym
# Processing Record 1 of Set 14 | eureka
# Processing Record 2 of Set 14 | jhajjar
# Processing Record 3 of Set 14 | langerwehe
# Processing Record 4 of Set 14 | okha
# Processing Record 5 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 14 | ukiah
# Processing Record 7 of Set 14 | san juan
# Processing Record 8 of Set 14 | khovu-aksy
# Processing Record 9 of Set 14 | putina
# Processing Record 10 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 14 | katiola
# Processing Record 12 of Set 14 | lincoln
# Processing Record 13 of Set 14 | waitakere
# Processing Record 14 of Set 14 | beisfjord
# Processing Record 15 of Set 14 | nuevo progreso
# Processing Record 16 of Set 14 | vardo
# Processing Record 17 of Set 14 | aragarcas
# Processing Record 18 of Set 14 | crato
# Processing Record 19 of Set 14 | shache
# Processing Record 20 of Set 14 | horasan
# Processing Record 21 of Set 14 | mareeba
# Processing Record 22 of Set 14 | villa maria
# Processing Record 23 of Set 14 | kyabram
# Processing Record 24 of Set 14 | cape coast
# Processing Record 25 of Set 14 | zhangjiakou
# Processing Record 26 of Set 14 | chistogorskiy
# Processing Record 27 of Set 14 | sao joao da barra
# Processing Record 28 of Set 14 | bambui
# Processing Record 29 of Set 14 | port moresby
# Processing Record 30 of Set 14 | keti bandar
# Processing Record 31 of Set 14 | nova olinda do norte
# Processing Record 32 of Set 14 | bastia
# Processing Record 33 of Set 14 | darlowo
# Processing Record 34 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 14 | ruteng
# Processing Record 37 of Set 14 | sturgis
# Processing Record 38 of Set 14 | buraydah
# Processing Record 39 of Set 14 | airai
# Processing Record 40 of Set 14 | finnsnes
# Processing Record 41 of Set 14 | itupiranga
# Processing Record 42 of Set 14 | shumskiy
# Processing Record 43 of Set 14 | bowmore
# Processing Record 44 of Set 14 | salto del guaira
# Processing Record 45 of Set 14 | kharp
# Processing Record 46 of Set 14 | lazaro cardenas
# Processing Record 47 of Set 14 | kadarkut
# Processing Record 48 of Set 14 | demidov
# Processing Record 49 of Set 14 | ipixuna
# Processing Record 50 of Set 14 | kodinar
# Processing Record 1 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 15 | zaozerne
# Processing Record 3 of Set 15 | catuday
# Processing Record 4 of Set 15 | coromandel
# Processing Record 5 of Set 15 | koygorodok
# Processing Record 6 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 15 | toora-khem
# Processing Record 8 of Set 15 | namatanai
# Processing Record 9 of Set 15 | armeria
# Processing Record 10 of Set 15 | nioki
# Processing Record 11 of Set 15 | watertown
# Processing Record 12 of Set 15 | sakete
# Processing Record 13 of Set 15 | saint-pierre
# Processing Record 14 of Set 15 | bom jesus
# Processing Record 15 of Set 15 | delhi
# Processing Record 16 of Set 15 | nanchang
# Processing Record 17 of Set 15 | harwich
# Processing Record 18 of Set 15 | coahuayana
# Processing Record 19 of Set 15 | richards bay
# Processing Record 20 of Set 15 | mayskiy
# Processing Record 21 of Set 15 | goiatuba
# Processing Record 22 of Set 15 | do rud
# City not found. Skipping...
# Processing Record 23 of Set 15 | kholm
# Processing Record 24 of Set 15 | sola
# Processing Record 25 of Set 15 | sakakah
# Processing Record 26 of Set 15 | dingle
# Processing Record 27 of Set 15 | kerrobert
# Processing Record 28 of Set 15 | cervo
# Processing Record 29 of Set 15 | guaruja
# Processing Record 30 of Set 15 | buchanan
# Processing Record 31 of Set 15 | buin
# Processing Record 32 of Set 15 | miramar
# Processing Record 33 of Set 15 | padang
# Processing Record 34 of Set 15 | havelock
# Processing Record 35 of Set 15 | koumac
# Processing Record 36 of Set 15 | trairi
# Processing Record 37 of Set 15 | hearst
# Processing Record 38 of Set 15 | skibbereen
# Processing Record 39 of Set 15 | ankang
# Processing Record 40 of Set 15 | bambanglipuro
# Processing Record 41 of Set 15 | kupang
# Processing Record 42 of Set 15 | malakal
# Processing Record 43 of Set 15 | togur
# Processing Record 44 of Set 15 | saint-francois
# Processing Record 45 of Set 15 | qujing
# Processing Record 46 of Set 15 | charleston
# Processing Record 47 of Set 15 | muravlenko
# Processing Record 48 of Set 15 | liverpool
# Processing Record 49 of Set 15 | indianola
# Processing Record 50 of Set 15 | abapo
# Processing Record 1 of Set 16 | semey
# Processing Record 2 of Set 16 | chapada dos guimaraes
# Processing Record 3 of Set 16 | asosa
# Processing Record 4 of Set 16 | yar-sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Grand Gaube      MU -20.0064   57.6608     77.00        79         100
# 1      Hazorasp      UZ  41.3194   61.0742     60.80        31           0
# 2         Bluff      NZ -46.6000  168.3333     52.00        94         100
# 3        Camaná      PE -16.6228  -72.7111     67.73        86          69
# 4  Ponta do Sol      PT  32.6667  -17.1000     60.01        83          69
# 5        Tūkrah      LY  32.5341   20.5791     69.01        32          34
# 6   Port Alfred      ZA -33.5906   26.8910     66.38        80           1
# 7  Punta Arenas      CL -53.1500  -70.9167     46.40        93          90
# 8     Cape Town      ZA -33.9258   18.4232     57.20        94          20
# 9       Mataura      NZ -46.1927  168.8643     52.00        94         100
#
#    Wind Speed Current Description
# 0        8.99     overcast clouds
# 1       11.50           clear sky
# 2       20.56     overcast clouds
# 3        8.23       broken clouds
# 4        5.99       broken clouds
# 5       24.54    scattered clouds
# 6       20.38           clear sky
# 7        5.75                mist
# 8       10.36          few clouds
# 9        5.46     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
